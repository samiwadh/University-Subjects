# %%
import pandas as pd

# %%
from pymongo import MongoClient
client = MongoClient('localhost', 27017)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from pymongo import MongoClient
#       2 client = MongoClient('localhost', 27017)
#
# ModuleNotFoundError: No module named 'pymongo'

# %%
pip install pymongo
# Out:
# ...
#    ---------------------------------------- 0.0/859.2 kB ? eta -:--:--
#    ------------ --------------------------- 262.1/859.2 kB ? eta -:--:--
#    ------------------------------------ --- 786.4/859.2 kB 2.1 MB/s eta 0:00:01
#    ---------------------------------------- 859.2/859.2 kB 1.7 MB/s  0:00:00
# ...
#
#    ---------------------------------------- 0/2 [dnspython]
#    ---------------------------------------- 0/2 [dnspython]
#    -------------------- ------------------- 1/2 [pymongo]
#    -------------------- ------------------- 1/2 [pymongo]
#    -------------------- ------------------- 1/2 [pymongo]
#    ---------------------------------------- 2/2 [pymongo]
#
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pymongo
print(pymongo.__version__)
# Out:
# 4.15.4

# %%
# connecting to MongoDB server 
from pymongo import MongoClient

# Connect to local MongoDB
client = MongoClient('localhost', 27017)

# %%
#How to connect to Neo4j from Python using py2neo
from py2neo import Graph
graph = Graph("bolt://localhost:7687", auth=("neo4j", "DataManLab"))  # replace with your username and password
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 2
#       1 #How to connect to Neo4j from Python using py2neo
# ----> 2 from py2neo import Graph
#       3 graph = Graph("bolt://localhost:7687", auth=("neo4j", "DataManLab"))  # replace with your username and password
#
# ModuleNotFoundError: No module named 'py2neo'

# %%
#How to connect to Neo4j from Python using py2neo
from py2neo import Graph
graph = Graph("bolt://localhost:7687", auth=("neo4j", "DataManLab"))  # replace with your username and password
# Out:
# ---------------------------------------------------------------------------
#
# ModuleNotFoundError                       Traceback (most recent call last)
#
# Cell In[7], line 2
#
#       1 #How to connect to Neo4j from Python using py2neo
#
# ----> 2 from py2neo import Graph
#
#       3 graph = Graph("bolt://localhost:7687", auth=("neo4j", "DataManLab"))  # replace with your username and password
#
#
#
# ModuleNotFoundError: No module named 'py2neo'

# %%
# !pip install py2neo
# Out:
# ...
#
#    ------------------------------ --------- 3/4 [py2neo]
#    ---------------------------------------- 4/4 [py2neo]
#
# ...

# %%
#How to connect to Neo4j from Python using py2neo

from py2neo import Graph
graph = Graph("bolt://localhost:7687", auth=("neo4j", "HitmanWadho"))
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
